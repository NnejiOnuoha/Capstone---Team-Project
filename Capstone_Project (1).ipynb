# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # New section

# %%
from google.colab import files

# Upload the Excel file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ca0cc8b1-6a4b-423e-9283-2f2f146ee0bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ca0cc8b1-6a4b-423e-9283-2f2f146ee0bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Assuming the file uploaded is named 'Room8 Finder Survey (Responses).xlsx'
df = pd.read_excel('Room8 Finder Survey (Responses).xlsx')

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#                 Timestamp                 Email Address  \
# 0 2024-03-09 02:07:04.180   ugwumodestachisom@gmail.com
# 1 2024-03-09 06:09:52.899  busarioyindamola20@gmail.com
# 2 2024-03-09 08:32:32.754       talk2brukayat@yahoo.com
# 3 2024-03-09 09:40:31.568       lawalnabeelah@gmail.com
# 4 2024-03-09 09:48:55.006          ighosharon@gmail.com
#
#   What is your age range? What is your gender?  \
# 0                   16-25               Female
# 1                   26-35               Female
# 2                   36-45               Female
# 3                   16-25               Female
# 4                   26-35               Female
#
#   Where is your location within Nigeria? What is your occupation?  \
# 0                                  Enugu                   Others
# 1                           Kwara state                   Student
# 2                                 Lagos                    Others
# 3                                  Lagos                   Corper
# ...

# %%
df.head()
# Out:
#                 Timestamp                 Email Address  \
# 0 2024-03-09 02:07:04.180   ugwumodestachisom@gmail.com
# 1 2024-03-09 06:09:52.899  busarioyindamola20@gmail.com
# 2 2024-03-09 08:32:32.754       talk2brukayat@yahoo.com
# 3 2024-03-09 09:40:31.568       lawalnabeelah@gmail.com
# 4 2024-03-09 09:48:55.006          ighosharon@gmail.com
#
#   What is your age range? What is your gender?  \
# 0                   16-25               Female
# 1                   26-35               Female
# 2                   36-45               Female
# 3                   16-25               Female
# 4                   26-35               Female
#
#   Where is your location within Nigeria? What is your occupation?  \
# 0                                  Enugu                   Others
# 1                           Kwara state                   Student
# 2                                 Lagos                    Others
# 3                                  Lagos                   Corper
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 17 columns):
#  #   Column                                                                                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                  --------------  -----
#  0   Timestamp                                                                                                                                                                               71 non-null     datetime64[ns]
#  1   Email Address                                                                                                                                                                           71 non-null     object
# ...

# %% [markdown]
# **DATA CLEANING**

# %%
# Drop the 'Timestamp' and 'Email Address' columns
df_cleaned = df.drop(columns=['Timestamp', 'Email Address'])

# Display the first few rows of the cleaned DataFrame
print(df_cleaned.head())
# Out:
#   What is your age range? What is your gender?  \
# 0                   16-25               Female
# 1                   26-35               Female
# 2                   36-45               Female
# 3                   16-25               Female
# 4                   26-35               Female
#
#   Where is your location within Nigeria? What is your occupation?  \
# 0                                  Enugu                   Others
# 1                           Kwara state                   Student
# 2                                 Lagos                    Others
# 3                                  Lagos                   Corper
# 4                                  Warri                 Business
#
#   What do you think about searching for a roommate or accomodations through agents?  \
# 0  I think that will be time saving, but I'm skep...
# 1  It's usually stressful and time consuming. It'...
# 2                                     It's strassful
# ...

# %%
df_cleaned.head(10)
# Out:
#   What is your age range? What is your gender?  \
# 0                   16-25               Female
# 1                   26-35               Female
# 2                   36-45               Female
# 3                   16-25               Female
# 4                   26-35               Female
# 5                   16-25               Female
# 6                   26-35               Female
# 7                   26-35                 Male
# 8                   26-35               Female
# 9                   26-35               Female
#
#   Where is your location within Nigeria? What is your occupation?  \
# 0                                  Enugu                   Others
# 1                           Kwara state                   Student
# 2                                 Lagos                    Others
# 3                                  Lagos                   Corper
# 4                                  Warri                 Business
# ...

# %%
# Check for missing values in each column
columns_with_missing_values = df_cleaned.columns[df_cleaned.isnull().any()]

# Display the columns with missing values
print(columns_with_missing_values)
# Out:
# Index(['Where is your location within Nigeria?',
#        'Have you ever faced any challenges trying to find suitable accommodation? If yes how did you tackle it?',
#        'What location are you likely to seek for an apartment or roommate?',
#        'On a scale of 1-10 how did you enjoy your experience while using the app?',
#        'Were there features that stood out for you? If yes, what were they?',
#        'Were there specific features you wish the app had? ',
#        'If you haven’t used such an app or come across it, will you love to use an app that caters for your rooms and accommodation needs?',
#        'What features will you like to look out for in such app?'],
#       dtype='object')

# %%
# Replace empty rows in the specified column with 'no'
df_cleaned['Have you ever faced any challenges trying to find suitable accommodation? If yes how did you tackle it?'] = df_cleaned['Have you ever faced any challenges trying to find suitable accommodation? If yes how did you tackle it?'].fillna('no')

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 15 columns):
#  #   Column                                                                                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                  --------------  -----
#  0   What is your age range?                                                                                                                                                                 71 non-null     object
#  1   What is your gender?                                                                                                                                                                    71 non-null     object
# ...

# %%
# Replace empty rows in the specified column with 'unknown'
df_cleaned['Where is your location within Nigeria?'] = df_cleaned['Where is your location within Nigeria?'].fillna('unknown')

# %%
df_cleaned.sample(20)
# Out:
#    What is your age range? What is your gender?  \
# 34                   36-45               Female
# 45                   26-35                 Male
# 52                   16-25                 Male
# 6                    26-35               Female
# 54                   16-25                 Male
# 9                    26-35               Female
# 59                   26-35               Female
# 41                   26-35               Female
# 48                   26-35               Female
# 11                   26-35               Female
# 39                   26-35               Female
# 13                   26-35                 Male
# 10                   16-25                 Male
# 26                   16-25               Female
# 24                   16-25                 Male
# 2                    36-45               Female
# 53                   16-25               Female
# 40                   16-25               Female
# ...

# %%
# Replace empty rows in the specified column with 'undecided'
df_cleaned['What location are you likely to seek for an apartment or roommate?'] = df_cleaned['What location are you likely to seek for an apartment or roommate?'].fillna('undecided')

# %%
# Replace empty rows in the specified column with 'No'
df_cleaned['Were there features that stood out for you? If yes, what were they?'] = df_cleaned['Were there features that stood out for you? If yes, what were they?'].fillna('No')

# %%
# Replace empty rows in the specified column with 'undecided'
df_cleaned['Were there specific features you wish the app had? '] = df_cleaned['Were there specific features you wish the app had? '].fillna('undecided')

# %%
# Replace empty rows in the specified column with 'undecided'
df_cleaned['If you haven’t used such an app or come across it, will you love to use an app that caters for your rooms and accommodation needs?'] = df_cleaned['If you haven’t used such an app or come across it, will you love to use an app that caters for your rooms and accommodation needs?'].fillna('undecided')

# %%
# Check for missing values in each column
missing_values = df_cleaned.isnull().sum()

# Display the columns with missing values
print(missing_values)
# Out:
# What is your age range?                                                                                                                                                                    0
# What is your gender?                                                                                                                                                                       0
# Where is your location within Nigeria?                                                                                                                                                     2
# What is your occupation?                                                                                                                                                                   0
# What do you think about searching for a roommate or accomodations through agents?                                                                                                          0
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 15 columns):
#  #   Column                                                                                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                  --------------  -----
#  0   What is your age range?                                                                                                                                                                 71 non-null     object
#  1   What is your gender?                                                                                                                                                                    71 non-null     object
# ...

# %%
# Replace empty rows in the specified column with 'known'
df_cleaned['What features will you like to look out for in such app?'] = df_cleaned['What features will you like to look out for in such app?'].fillna('unknown')

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 15 columns):
#  #   Column                                                                                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                  --------------  -----
#  0   What is your age range?                                                                                                                                                                 71 non-null     object
#  1   What is your gender?                                                                                                                                                                    71 non-null     object
# ...

# %%
# Replace 'Imi' with 'Imo' in the specified column
df_cleaned['Where is your location within Nigeria?'] = df_cleaned['Where is your location within Nigeria?'].replace('Imi', 'Imo')

# %%
# Replace the label of one "Lagos" entry to match the other
df_cleaned.loc[df_cleaned['What location are you likely to seek for an apartment or roommate?'] == 'Lagos ', 'What location are you likely to seek for an apartment or roommate?'] = 'Lagos'

# %%
# Replace the label of one "Lagos" entry to match the other
df_cleaned.loc[df_cleaned['Where is your location within Nigeria?'] == 'Lagos ', 'Where is your location within Nigeria?'] = 'Lagos'

# %%
# Replace the label of one "Abuja" entry to match the other
df_cleaned.loc[df_cleaned['Where is your location within Nigeria?'] == 'Abuja ', 'Where is your location within Nigeria?'] = 'Abuja'

# %%
# Replace 'location' with 'Location' in the specified column
df_cleaned['How will you prioritize the following factors when searching for an accommodation or roommate? Location, budget, lifestyle, preference, religion? Arrange them from highest to least. '] = df_cleaned['How will you prioritize the following factors when searching for an accommodation or roommate? Location, budget, lifestyle, preference, religion? Arrange them from highest to least. '].replace('location', 'Location')

# %%
# Replace 'Corp member' with 'Corper' in the specified column
df_cleaned['What is your occupation?'] = df_cleaned['What is your occupation?'].replace('Corp member', 'Corper')

# %%
# Replace 'No' responses in the specified column with 'No responses'
df_cleaned.loc[df_cleaned['Have you ever used an app to search for an accommodation or roommate? If yes what app did you use and how was your experience using it? '] == 'No', 'On a scale of 1-10 how did you enjoy your experience while using the app?'] = 'No responses'

# %%
# Extract the relevant column for app usage
app_usage_column = 'Have you ever used an app to search for an accommodation or roommate? If yes what app did you use and how was your experience using it? '

# Create a mask for every other response (excluding "Yes")
mask = df_cleaned[app_usage_column].ne('Yes').cumsum().mod(2).eq(1)

# Update the responses to "No" where the mask is True
df_cleaned.loc[mask, app_usage_column] = 'No'

# %%
# Replace 'N o' with 'No' in the specified column
df_cleaned['Have you ever used an app to search for an accommodation or roommate? If yes what app did you use and how was your experience using it? '] = df_cleaned['Have you ever used an app to search for an accommodation or roommate? If yes what app did you use and how was your experience using it? '].replace('N o', 'No')

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 15 columns):
#  #   Column                                                                                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                  --------------  -----
#  0   What is your age range?                                                                                                                                                                 71 non-null     object
#  1   What is your gender?                                                                                                                                                                    71 non-null     object
# ...

# %%
# Replace empty rows in the specified column with 'No responses'
df_cleaned['On a scale of 1-10 how did you enjoy your experience while using the app?'] = df_cleaned['On a scale of 1-10 how did you enjoy your experience while using the app?'].fillna('No responses')

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 15 columns):
#  #   Column                                                                                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                  --------------  -----
#  0   What is your age range?                                                                                                                                                                 71 non-null     object
#  1   What is your gender?                                                                                                                                                                    71 non-null     object
# ...

# %% [markdown]
# **Exploratory Data Analysis**

# %%
# Analyze the distribution of age ranges
plt.figure(figsize=(12, 6))
sns.countplot(data=df_cleaned, x='What is your age range?')
plt.title('Distribution of Age Ranges')
plt.xlabel('Age Range')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Analyze the distribution of genders
plt.figure(figsize=(8, 5))
sns.countplot(data=df_cleaned, x='What is your gender?')
plt.title('Distribution of Genders')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Explore the occupations of respondents
plt.figure(figsize=(12, 6))
sns.countplot(data=df_cleaned, y='What is your occupation?')
plt.title('Distribution of Occupations')
plt.xlabel('Count')
plt.ylabel('Occupation')
plt.show()

# %%
# Get the top five most selected locations
top_locations = df_cleaned['Where is your location within Nigeria?'].value_counts().head(5)

# Plot the top five locations
plt.figure(figsize=(10, 6))
sns.barplot(x=top_locations.values, y=top_locations.index)
plt.title('Top Five Most Selected Locations within Nigeria')
plt.xlabel('Count')
plt.ylabel('Location within Nigeria')
plt.show()

# %%
# Assuming df_cleaned is your DataFrame
location_column = "What location are you likely to seek for an apartment or roommate?"

# Extract the responses
location_responses = df_cleaned[location_column].value_counts()

# Plotting the responses
plt.figure(figsize=(10, 6))
location_responses.plot(kind='bar')
plt.title("Preferred Locations for Apartment or Roommate Search")
plt.xlabel("Location")
plt.ylabel("Number of Respondents")
plt.xticks(rotation=45, ha='right')  # Rotate x-labels for better readability
plt.tight_layout()
plt.show()

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Download VADER lexicon
import nltk
nltk.download('vader_lexicon')

# Initialize the VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Function to get sentiment polarity score
def get_sentiment(text):
    scores = sid.polarity_scores(text)
    return scores['compound']

# Apply sentiment analysis to the text responses
df_cleaned['Sentiment Score'] = df_cleaned['What do you think about searching for a roommate or accomodations through agents?'].apply(get_sentiment)

# Visualize sentiment distribution
plt.figure(figsize=(8, 5))
sns.histplot(data=df_cleaned, x='Sentiment Score', bins=20, kde=True, color='skyblue')
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.show()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Define a function to categorize sentiment scores
def categorize_sentiment(score):
    if score == 0:
        return 'Neutral'
    elif 0 < score <= 0.5:
        return 'Positive'
    elif 0.5 < score <= 1:
        return 'Very Positive'
    elif -0.5 <= score < 0:
        return 'Negative'
    elif -1 <= score < -0.5:
        return 'Very Negative'

# Apply the function to create a new column for sentiment categories
df_cleaned['Sentiment Category'] = df_cleaned['Sentiment Score'].apply(categorize_sentiment)

# Visualize sentiment distribution based on categories
plt.figure(figsize=(8, 5))
sns.countplot(data=df_cleaned, x='Sentiment Category', palette='coolwarm')
plt.title('Distribution of Sentiment Categories')
plt.xlabel('Sentiment Category')
plt.ylabel('Frequency')
plt.show()
# Out:
# <ipython-input-36-6acb526c03e3>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_cleaned, x='Sentiment Category', palette='coolwarm')

# %%
priority_column = 'How will you prioritize the following factors when searching for an accommodation or roommate? Location, budget, lifestyle, preference, religion? Arrange them from highest to least. '

# Drop rows with missing values in the priority column
df_cleaned.dropna(subset=[priority_column], inplace=True)

# Split the responses into individual factors
df_cleaned['Priorities'] = df_cleaned[priority_column].str.split(', ')

# Flatten the list of priorities, handling NaN values
all_priorities = [factor for sublist in df_cleaned['Priorities'].dropna() for factor in sublist]

# Count the occurrences of each factor
priority_counts = pd.Series(all_priorities).value_counts()

# Define the order of factors
priority_order = ['Location', 'Budget', 'Lifestyle', 'Preference', 'Religion']

# Sort the factors based on their counts and priority order
sorted_priorities = [factor for factor in priority_order if factor in priority_counts.index]

# Plot the priority order
plt.figure(figsize=(10, 6))
plt.barh(range(len(sorted_priorities)), priority_counts[sorted_priorities], color='skyblue')
plt.yticks(range(len(sorted_priorities)), sorted_priorities)
plt.xlabel('Count')
plt.ylabel('Priority')
plt.title('Priority of Factors when Searching for Accommodation or Roommate')
plt.gca().invert_yaxis()  # Invert y-axis to display highest priority at the top
plt.show()

# %%
app_usage_column = 'Have you ever used an app to search for an accommodation or roommate? If yes what app did you use and how was your experience using it? '

# Filter out responses other than "Yes" and "No"
app_usage_counts = df_cleaned[app_usage_column].value_counts().loc[['Yes', 'No']]

# Plot the doughnut chart with custom colors
plt.figure(figsize=(8, 6))
colors = ['skyblue', 'lightcoral']  # Using light red and sky blue colors
plt.pie(app_usage_counts, labels=app_usage_counts.index, autopct='%1.1f%%', colors=colors, wedgeprops=dict(width=0.3))
plt.title('Respondents Usage of Apps for Searching Accommodations or Roommates')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Download VADER lexicon
import nltk
nltk.download('vader_lexicon')

# Assuming the column name containing participants' sentiments is 'Interest in Using App'
interest_column = "If you haven’t used such an app or come across it, will you love to use an app that caters for your rooms and accommodation needs?"

# Instantiate the VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Define a function to categorize sentiment scores
def categorize_sentiment(score):
    if score == 0:
        return 'Neutral'
    elif 0 < score <= 0.5:
        return 'Positive'
    elif 0.5 < score <= 1:
        return 'Very Positive'
    elif -0.5 <= score < 0:
        return 'Negative'
    elif -1 <= score < -0.5:
        return 'Very Negative'

# Define a function to get sentiment polarity score
def get_sentiment(text):
  if isinstance(text, str):
    return sid.polarity_scores(text)['compound']
  else:
      return text

# Apply the function to the interest column to get sentiment scores
df_cleaned['Interest Sentiment Score'] = df_cleaned[interest_column].apply(get_sentiment)

# Apply the function to categorize sentiment scores
df_cleaned['Interest Sentiment Category'] = df_cleaned['Interest Sentiment Score'].apply(categorize_sentiment)

# Plot the sentiment distribution based on categories
plt.figure(figsize=(10, 6))
sns.countplot(data=df_cleaned, x='Interest Sentiment Category', palette='coolwarm')
plt.title('Sentiment Distribution towards Using Accommodation App')
plt.xlabel('Sentiment Category')
plt.ylabel('Frequency')
plt.show()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# <ipython-input-44-517a135c1b94>:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_cleaned, x='Interest Sentiment Category', palette='coolwarm')

# %%
# Column containing the willingness to pay information
willingness_to_pay_column = 'Are you willing to pay a token  or subscribe to an app to take away that burden of search from you?'

# Extract the sentiment information
sentiments = df_cleaned[willingness_to_pay_column].value_counts()

# Define the categories you want to keep
categories_to_keep = ['Yes', 'No', 'Maybe']

# Sum the counts of all categories not in categories_to_keep
other_count = sentiments[~sentiments.index.isin(categories_to_keep)].sum()

# Remove categories not in categories_to_keep and add Others category
sentiments = sentiments[sentiments.index.isin(categories_to_keep)]
sentiments['Others'] = other_count

# Define colors for each category
colors = ['skyblue', 'lightgreen', 'lightcoral', 'lightgrey']

# Define label distances for each category
label_distances = [0.6, 0.6, 0.6, 0.5]  # Adjust the label distance for 'Others'

# Plotting the sentiments as a donut chart
plt.figure(figsize=(8, 6))
plt.pie(sentiments, labels=sentiments.index, colors=colors, autopct='%1.1f%%', startangle=90, pctdistance=0.85, wedgeprops=dict(width=0.4), labeldistance=1.1)
plt.title("Respondents' Sentiment towards Paying for Accommodation Search Apps")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Add a circle at the center to create the donut effect
centre_circle = plt.Circle((0, 0), 0.3, color='white', linewidth=0)
plt.gca().add_artist(centre_circle)

# Show the plot
plt.show()

# %% [markdown]
# Visualization

# %%
df.columns
# Out:
# Index(['Timestamp', 'Email Address', 'What is your age range?',
#        'What is your gender?', 'Where is your location within Nigeria?',
#        'What is your occupation?',
#        'What do you think about searching for a roommate or accomodations through agents?',
#        'Have you ever faced any challenges trying to find suitable accommodation? If yes how did you tackle it?',
#        'What location are you likely to seek for an apartment or roommate?',
#        'How will you prioritize the following factors when searching for an accommodation or roommate? Location, budget, lifestyle, preference, religion? Arrange them from highest to least. ',
#        'Have you ever used an app to search for an accommodation or roommate? If yes what app did you use and how was your experience using it? ',
#        'On a scale of 1-10 how did you enjoy your experience while using the app?',
#        'Were there features that stood out for you? If yes, what were they?',
# ...

# %%
# Group data by location and gender
grouped_data = df.groupby(["Where is your location within Nigeria?", "What is your gender?"]).size().unstack()

# Create bar chart
plt.figure()
grouped_data.plot(kind="bar", stacked=True)
plt.title("Gender Response by Location")
plt.xlabel("Location")
plt.ylabel("Count")
plt.show()

# %%
# Group data by age range and gender
grouped_data = df.groupby(["What is your age range?", "What is your gender?"]).size().unstack()

# Create bar chart
plt.figure()
grouped_data.plot(kind="bar", stacked=True)
plt.title("Gender Response by Age Range")
plt.xlabel("Age Range")
plt.ylabel("Count")
plt.show()

# %%
# Group data by occupation and gender
grouped_data = df.groupby(["What is your occupation?", "What is your gender?"]).size().unstack()

# Create bar chart
plt.figure()
grouped_data.plot(kind="bar", stacked=True)
plt.title("Gender Distribution by Occupation")
plt.xlabel("Occupation")
plt.ylabel("Count")
plt.show()

# %%
df['What is your gender?'].dtype
df['What is your gender?'] = df['What is your gender?'].astype('category').cat.codes

plt.figure()
df.boxplot(column="What is your gender?", by="Where is your location within Nigeria?", rot=90)
plt.title("Box Plot of Gender Responses by Location")
plt.xlabel("Location")
plt.ylabel("Gender")
plt.show()

# %%
age_responses = df.iloc[:, 0]

# Count the occurrences of each age response
age_counts = age_responses.value_counts()

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(pd.DataFrame(age_counts), annot=True, cmap="YlGnBu")
plt.xlabel("Age", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.yticks(rotation=0)
plt.title("Heatmap of Age Responses", fontsize=16)
plt.show()
